# %%
import pandas as pd
import numpy as np

b1 =pd.read_csv("endangeredLang.csv")

b1.head(n=4)
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
#
#           Country codes alpha 3 Degree of endangerment  Number of speakers  \
# 0                           ITA             Vulnerable           7500000.0
# 1                           ITA             Vulnerable           5000000.0
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable           4800000.0
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable           4000000.0
#
#    Latitude  Longitude                        Description of the location
# 0   40.9798    15.2490  Campania, Lucania (Basilicata), Abruzzi (Abruz...
# ...

# %%
b1.Countries
# Out:
# 0                                                   Italy
# 1                                                   Italy
# 2       Germany, Denmark, Netherlands, Poland, Russian...
# 3       Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                      Italy, Switzerland
#                               ...
# 2717                                                Japan
# 2718                                             Colombia
# 2719                                             Colombia
# 2720                                      India, Pakistan
# 2721                                                 Oman
# Name: Countries, Length: 2722, dtype: object

# %%
a1 = b1[["ID","Countries"]]
a1[2:5]
# Out:
#     ID                                          Countries
# 2  383  Germany, Denmark, Netherlands, Poland, Russian...
# 3  335  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4  382                                 Italy, Switzerland

# %%
a2 = b1[b1["Number of speakers"] <5000] 
a1
# Out:
#         ID                                          Countries
# 0     1022                                              Italy
# 1     1023                                              Italy
# 2      383  Germany, Denmark, Netherlands, Poland, Russian...
# 3      335  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4      382                                 Italy, Switzerland
# ...    ...                                                ...
# 2717  1972                                              Japan
# 2718  2018                                           Colombia
# 2719  2015                                           Colombia
# 2720  2716                                    India, Pakistan
# 2721  2177                                               Oman
#
# [2722 rows x 2 columns]

# %% [markdown]
# Column/Row

# %%
z1 = pd.DataFrame(b1)
z1
# Out:
#         ID    Name in English  \
# 0     1022      South Italian
# 1     1023           Sicilian
# 2      383          Low Saxon
# 3      335         Belarusian
# 4      382            Lombard
# ...    ...                ...
# 2717  1972           Yonaguni
# 2718  2018             Yucuna
# 2719  2015  Yurutí (Colombia)
# 2720  2716          Zangskari
# 2721  2177            Zidgali
#
#                                               Countries  \
# 0                                                 Italy
# 1                                                 Italy
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# ...

# %%
z1.drop(z1.index[0],inplace = True)

# %%
z1.drop(z1.index[:2],inplace = True)

# %%
z1.drop(["Longitude"], axis = 1 )
# Out:
#         ID    Name in English  \
# 3      335         Belarusian
# 4      382            Lombard
# 5      405             Romani
# 6     2211   Yiddish (Israel)
# 7     1586              Gondi
# ...    ...                ...
# 2717  1972           Yonaguni
# 2718  2018             Yucuna
# 2719  2015  Yurutí (Colombia)
# 2720  2716          Zangskari
# 2721  2177            Zidgali
#
#                                               Countries  \
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# 5     Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                                Israel
# 7                                                 India
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# ...
