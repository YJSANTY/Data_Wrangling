# %%
Columns/Rows

# %%
import pandas as pd
import numpy as np

b1 = pd.read_csv("StudentsPerformance.csv")
b1.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
new_names=["Gen","Grp","Lvl","Lun","Prep","Cou","Math","Read","Wri"]
b2 = pd.read_csv("StudentsPerformance.csv", names = new_names)
b2
# Out:
#          Gen             Grp                          Lvl           Lun  \
# 0     gender  race/ethnicity  parental level of education         lunch
# 1     female         group B            bachelor's degree      standard
# 2     female         group C                 some college      standard
# 3     female         group B              master's degree      standard
# 4       male         group A           associate's degree  free/reduced
# ...      ...             ...                          ...           ...
# 996   female         group E              master's degree      standard
# 997     male         group C                  high school  free/reduced
# 998   female         group C                  high school  free/reduced
# 999   female         group D                 some college      standard
# 1000  female         group D                 some college  free/reduced
#
#                          Prep         Cou           Math           Read  Wri
# ...

# %%
b2.rename(columns = {"Gen":"Generation","Math":"Mat"} , inplace =True)
b2
# Out:
#      Generation             Grp                          Lvl           Lun  \
# 0        gender  race/ethnicity  parental level of education         lunch
# 1        female         group B            bachelor's degree      standard
# 2        female         group C                 some college      standard
# 3        female         group B              master's degree      standard
# 4          male         group A           associate's degree  free/reduced
# ...         ...             ...                          ...           ...
# 996      female         group E              master's degree      standard
# 997        male         group C                  high school  free/reduced
# 998      female         group C                  high school  free/reduced
# 999      female         group D                 some college      standard
# 1000     female         group D                 some college  free/reduced
#
# ...

# %%
b2["Read"].describe()
# Out:
# count     1001
# unique      78
# top         74
# freq        35
# Name: Read, dtype: object

# %%
# b2["Read"] = b2['Read'].astype(float)
# b2["Read"].describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-c4d3d07252fa> in <cell line: 1>()
# ----> 1 b2["Read"] = b2['Read'].astype(float)
#       2 b2["Read"].describe()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
# ...

# %% [markdown]
# If time is given in the csv file then use uthe time to differnetiate it

# %%
# b2.date = pd.to_datetime(b2.date)
# b2.set_index('date',inplace =True)

# b2['2016']
# b2['2015':'2019']
