# %%
import pandas as pd
import numpy as np

b1 = read_csv("NFA 2018.csv")
b1.head()
seac = b1[b1.UN_subregion=="South-Eastern Asia"]
seac.head()
seac_1 = b1[b1.forest_namme>=5]
seac_1

# %%
year= [1990,1995,2000]

#below two are different commands one gives true or false value
#second gives the rows which are true for the condition

seac_1.year.isin(year)
seac_1[seac_1.year.isin(year)]

alpha= list(nfa.UN_region.unique())

# %%
#  ~ gives not so itr prints whatever ture as false and vice versa

nfa_coun = b1[~b1.Un_region.isin(alpha)]
b1[nfa_coun] 

b1[~b1.Un_region.isin(alpha) & b1.forest_namme>=5]

# %% [markdown]
# Fuzzy system

# %%
pip install fuzzywuzzy
from fuzzywuzzy import fuzz 

fuzz.ratio("word_1","word_2")  #checks words with order
fuzz.partial_ratio("word_1","word_2") #partial checking
fuzz.token_sort_ratio("word_1","word_2") # doesnt check the order
